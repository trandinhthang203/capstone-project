# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.messages import HumanMessage, SystemMessage
from dotenv import load_dotenv
import os

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# %%
llm = ChatGoogleGenerativeAI(
    api_key = GEMINI_API_KEY,
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
messages = [
    SystemMessage(content = f"""Bạn là chuyên gia về thủ tục hành chính Việt Nam, hãy đọc mẫu đơn từ và thông tin từ người dùng cung cấp sau đó điền mẫu đơn hoàn chỉnh\
        Nội dung mẫu đơn {fulltext}"""\
    ),
    HumanMessage(content = "Tôi tên Trần Đình Thắng, sinh ngày 27/07/2003, Nam")
]


ai_msg = llm.invoke(messages)

# %%
import sys
import os

print("Current dir:", os.getcwd())
# Out:
# Current dir: d:\capstone-project\notebooks

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

print("Project root:", project_root)
# Out:
# Project root: d:\capstone-project

# %%
if project_root not in sys.path:
    sys.path.insert(0, project_root)

for m in [
    "scripts", "scripts.models",
    "scripts.models.procedure",
    "scripts.models.method",
    "scripts.models.component",
    "scripts.models.basis"
]:
    sys.modules.pop(m, None)

print(sys.path)
# Out:
# ['C:\\Users\\trand\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\trand\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\trand\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\trand\\AppData\\Local\\Programs\\Python\\Python312', 'd:\\capstone-project\\venv', '', 'd:\\capstone-project\\venv\\Lib\\site-packages', 'd:\\capstone-project\\venv\\Lib\\site-packages\\win32', 'd:\\capstone-project\\venv\\Lib\\site-packages\\win32\\lib', 'd:\\capstone-project\\venv\\Lib\\site-packages\\Pythonwin', 'd:\\capstone-project', 'd:\\capstone-project']

# %%
from sqlalchemy.orm import Session
from app.core.config import settings
from app.db.session import get_db
from scripts.models.procedure import Thu_Tuc
from scripts.models.method import Cach_Thuc_Thuc_Hien
from scripts.models.component import Thanh_Phan_Ho_So
from scripts.models.basis import Can_Cu_Phap_Ly

db = next(get_db())
procedures = db.query(Thu_Tuc).first()
print(procedures.ten_thu_tuc)
# Out:
# d:\capstone-project\scripts\models\method.py:5: SAWarning: This declarative base already contains a class with the same class name and module name as scripts.models.method.Cach_Thuc_Thuc_Hien, and will be replaced in the string-lookup table.
#   class Cach_Thuc_Thuc_Hien(Base):
# d:\capstone-project\scripts\models\component.py:6: SAWarning: This declarative base already contains a class with the same class name and module name as scripts.models.component.Thanh_Phan_Ho_So, and will be replaced in the string-lookup table.
#   class Thanh_Phan_Ho_So(Base):
# d:\capstone-project\scripts\models\basis.py:5: SAWarning: This declarative base already contains a class with the same class name and module name as scripts.models.basis.Can_Cu_Phap_Ly, and will be replaced in the string-lookup table.
#   class Can_Cu_Phap_Ly(Base):
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[38], line 10
#       7 from scripts.models.basis import Can_Cu_Phap_Ly
#       9 db = next(get_db())
# ---> 10 procedures = db.query(Thu_Tuc).first()
#      11 print(procedures.ten_thu_tuc)
#
# File d:\capstone-project\venv\Lib\site-packages\sqlalchemy\orm\session.py:2941, in Session.query(self, *entities, **kwargs)
#    2921 def query(
#    2922     self, *entities: _ColumnsClauseArgument[Any], **kwargs: Any
#    2923 ) -> Query[Any]:
#    2924     """Return a new :class:`_query.Query` object corresponding to this
#    2925     :class:`_orm.Session`.
#    2926
#    (...)   2938
#    2939     """
# -> 2941     return self._query_cls(entities, self, **kwargs)
#
# File d:\capstone-project\venv\Lib\site-packages\sqlalchemy\orm\query.py:276, in Query.__init__(self, entities, session)
#     270 # session is usually present.  There's one case in subqueryloader
#     271 # where it stores a Query without a Session and also there are tests
#     272 # for the query(Entity).with_session(session) API which is likely in
#     273 # some old recipes, however these are legacy as select() can now be
#     274 # used.
#     275 self.session = session  # type: ignore
# --> 276 self._set_entities(entities)
#
# File d:\capstone-project\venv\Lib\site-packages\sqlalchemy\orm\query.py:289, in Query._set_entities(self, entities)
#     282 def _set_entities(
#     283     self,
#     284     entities: Union[
#     285         _ColumnsClauseArgument[Any], Iterable[_ColumnsClauseArgument[Any]]
#     286     ],
#     287 ) -> None:
#     288     self._raw_columns = [
# --> 289         coercions.expect(
#     290             roles.ColumnsClauseRole,
#     291             ent,
#     292             apply_propagate_attrs=self,
#     293             post_inspect=True,
#     294         )
#     295         for ent in util.to_list(entities)
#     296     ]
#
# File d:\capstone-project\venv\Lib\site-packages\sqlalchemy\sql\coercions.py:389, in expect(role, element, apply_propagate_attrs, argname, post_inspect, disable_inspection, **kw)
#     387 if insp is not None:
#     388     if post_inspect:
# --> 389         insp._post_inspect
#     390     try:
#     391         resolved = insp.__clause_element__()
#
# File d:\capstone-project\venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:1235, in HasMemoized.memoized_attribute.__get__(self, obj, cls)
#    1233 if obj is None:
#    1234     return self
# -> 1235 obj.__dict__[self.__name__] = result = self.fget(obj)
#    1236 obj._memoized_keys |= {self.__name__}
#    1237 return result
#
# File d:\capstone-project\venv\Lib\site-packages\sqlalchemy\orm\mapper.py:2733, in Mapper._post_inspect(self)
#    2722 @HasMemoized.memoized_attribute
#    2723 def _post_inspect(self):
#    2724     """This hook is invoked by attribute inspection.
#    2725
#    2726     E.g. when Query calls:
#    (...)   2731
#    2732     """
# -> 2733     self._check_configure()
#
# File d:\capstone-project\venv\Lib\site-packages\sqlalchemy\orm\mapper.py:2410, in Mapper._check_configure(self)
#    2402 @util.langhelpers.tag_method_for_warnings(
#    2403     "This warning originated from the `configure_mappers()` process, "
#    2404     "which was invoked automatically in response to a user-initiated "
#    (...)   2407 )
#    2408 def _check_configure(self) -> None:
#    2409     if self.registry._new_mappers:
# -> 2410         _configure_registries({self.registry}, cascade=True)
#
# File d:\capstone-project\venv\Lib\site-packages\sqlalchemy\orm\mapper.py:4227, in _configure_registries(registries, cascade)
#    4221     Mapper.dispatch._for_class(Mapper).before_configured()  # type: ignore # noqa: E501
#    4222     # initialize properties on all mappers
#    4223     # note that _mapper_registry is unordered, which
#    4224     # may randomly conceal/reveal issues related to
#    4225     # the order of mapper compilation
# -> 4227     _do_configure_registries(registries, cascade)
#    4228 finally:
#    4229     _already_compiling = False
#
# File d:\capstone-project\venv\Lib\site-packages\sqlalchemy\orm\mapper.py:4264, in _do_configure_registries(registries, cascade)
#    4256     e = sa_exc.InvalidRequestError(
#    4257         "One or more mappers failed to initialize - "
#    4258         "can't proceed with initialization of other "
#    (...)   4261         % (mapper, mapper._configure_failed)
#    4262     )
#    4263     e._configure_failed = mapper._configure_failed  # type: ignore
# -> 4264     raise e
#    4266 if not mapper.configured:
#    4267     try:
#
# InvalidRequestError: One or more mappers failed to initialize - can't proceed with initialization of other mappers. Triggering mapper: 'Mapper[Thu_Tuc(thu_tuc)]'. Original exception was: When initializing mapper Mapper[Thu_Tuc(thu_tuc)], expression 'Cach_Thuc_Thuc_Hien' failed to locate a name ('Cach_Thuc_Thuc_Hien'). If this is a class name, consider adding this relationship() to the <class 'scripts.models.procedure.Thu_Tuc'> class after both dependent classes have been defined.
