# %%
import pandas as pd
import numpy as np


df = pd.read_csv("D:\capstone-project\data\evaluation\co_con_nho_qa.csv")
df
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\c'
# <>:5: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\trand\AppData\Local\Temp\ipykernel_14756\3794260682.py:5: SyntaxWarning: invalid escape sequence '\c'
#   df = pd.read_csv("D:\capstone-project\data\evaluation\co_con_nho_qa.csv")
#                                               Câu hỏi  \
# 0   Hiện nay tôi đã kết hôn, chồng tôi là người Nh...
# 1   Con tôi chung sống với một anh sinh được một c...
# 2   Tôi hiện đang cư trú tại thành phố Hà Nội. Tôi...
# 3                                Bảo hiểm y tế là gì?
# 4   Vợ tôi mới sinh con, nay tôi muốn đăng ký khai...
# 5   Tôi có chồng người Mỹ, đăng ký kết hôn tại Việ...
# 6   Hiện tôi đang gặp khó khăn trong việc làm khai...
# 7   Do một số lý do về sức khỏe, chị tôi không thể...
# 8   Trước đây tôi đã kết hôn với một công dân Đức ...
# 9   Tôi là công dân Việt Nam, có con với một công ...
# 10  Tôi là công dân Việt Nam, cư trú tại quận Hoàn...
# ...
